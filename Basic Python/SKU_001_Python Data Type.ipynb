# %% [markdown]
# # Data Type In Python

# %% [markdown]
# ![Python%20Data%20Type.JPG](attachment:Python%20Data%20Type.JPG)

# %% [markdown]
# For any programming language Data Type is a very important factor, same as in Python. Variables can store data of different types, and different types can do different things.

# %% [raw]
# Below are the built in data type of Python:-
# Numeric
# Sequence Type
# Boolean
# Set
# Dictionary

# %% [markdown]
# ### Numeric

# %% [raw]
# Numeric data type represents the data in numeric value. Below is the sub category of numeric data type:-
#
# 	a. Integers: Any numeric value (positive or negative) which is whole number.
# 	b. Float: Float is used to represent real numbers and is written with a decimal point dividing the integer and fractional parts.
# 	c. Complex: A complex number has two parts, real part and imaginary part.Example: A+Bj (A is a real number and B is a  imaginary)
# 	We can create a complex number : Complex_num = complex(3,6)
# 	To get real and imaginary out from Complex.
# 	Complrex_num.real    Complrex_num.imag

# %% [markdown]
# #### A complex number has two parts, real part and imaginary part.

# %% [markdown]
# ###### How to create a complex number

# %%
## We can create complex number from two real numbers
complex_num = complex(3,9)
print(complex_num)
# Out:
# (3+9j)

# %%
complex_num.real
# Out:
# 3.0

# %%
complex_num.imag
# Out:
# 9.0

# %% [markdown]
# ### Sequence Type

# %% [markdown]
# Sequence Data Type is the collection of similar or different data types in python.Sequence allow to store multiple values in organized manner.

# %% [markdown]
# 	a. String : String is a collection of characters in a single quote, double-quote or triple quote.
# 	b. List : List is an ordered collection of data. In list we can store any type of data. That can be created in square brackets[]
# 	c. Tuple : Tuple is also an ordered collection of data like list. However, Tuple is immutable, tuple cannot be modified after it is created. That can be created in round brackets ().

# %% [markdown]
# ### Boolean

# %% [markdown]
# Boolean Data Type in python as same as in any other language. That has the built-in two values - True and False.

# %% [markdown]
# ### Set

# %% [markdown]
# A set is a collection of unordered data, means user cannot be sure at which order the items will appear.
# Set items are unchangeable, but user can add or remove items. But cannot replace by its order/index value.
# Cannot be any duplicate value in Set.

# %% [markdown]
# ### Dictionary

# %% [markdown]
# Dictionary in Python is an unordered collection of data.
# User can hold data in dictionary as key:value pair. Key-value. Each key-value pair in a Dictionary is separated by a colon:.
