# %% [markdown]
# # Introduction of Statistical Data Distributions

# %% [markdown]
# Distribution simply means collection or gathering of data, or scores, on variable. Generally, all these scores are arranged in specific order from smallest to largest. Then these scores can be presented graphically.

# %% [markdown]
# A distribution in statistics is a function that shows the possible values for a variable and how often they occur.
#
# Distributions are generally described in terms of their density or density functions. Density functions are simply described as functions that explain how proportion of data or likelihood of proportion of observations change over wide range of distribution. Density functions are of two types –

# %% [markdown]
# Distribution in statistics is a function that represents the possible values for a variable and how frequently they happen.

# %% [markdown]
# ## Categories of Distribution

# %% [markdown]
# ###### Frequency Distribution
# The number of times each numerical/categorical value occurs.

# %% [markdown]
# ###### Probability Distribution
# List of Probabilities associated with each of its possible numerical values.

# %% [markdown]
# ### Types of Statistical Data Distributions :

# %% [raw]
# • Normal Distribution (Gaussian/Normal Distribution)
# • Bernoulli Distribution
# • Binomial Distribution
# • Uniform Distribution
# • Poisson Distribution
# • Exponential Distribution

# %% [markdown]
# ## Normal Distribution (Gaussian)

# %% [markdown]
# ###### Gaussian/Normal Distribution curve – Data spread on Symmetrical distribution
#
# the normal distribution is also called the bell curve
#
# The data was distributed in 68%, 95%, and 99.7% manner (Empirical Rule). We expect the 99.7% of given data set should be under 1 standard deviation range, 95% of given data set should be under 2 standard deviation range, and 68% of data should be under 3 standard deviation range.

# %% [markdown]
# ###### Properties of a normal distribution
#
# The curve remains symmetric at the center.
# The area under the curve is 1.
# The mean, median, and mode are always equal.
# Exactly half value is on the left of the center and the other on the right.

# %% [markdown]
# ## Bernoulli Distribution:

# %% [markdown]
# Bernoulli Distribution is a type of discrete probability distribution where every experiment
# conducted asks a question that can be answered only in yes or no. In other words, the random
# variable can be 1 with a probability p or it can be 0 with a probability (1 - p). Such an
# experiment is called a Bernoulli trial.

# %% [markdown]
# A Bernoulli distribution is a kind of discrete probability distribution- a random trial that has two results. There is a special case that has the value n = 1, for example, a single coin toss.

# %% [markdown]
# ###### Characteristics of Bernoulli distribution

# %% [raw]
# The number of trials that have to be performed under a single experiment must be predefined.
# Each trial must have two outcomes that are success or failure.
# The success’ probability in each experiment should be the same.
# The experiment should be independent of each other, which means the outcome of one trial is not affected by the other’s trial outcome.

# %% [markdown]
# ###### Bernoulli Distribution Example

# %% [markdown]
# Suppose there is an experiment where you flip a coin that is fair. If the outcome of the flip
# heads, then you will win. This means that the probability of getting heads is p = 1/2. If X is
# the random variable following a Bernoulli Distribution, we get P (X = 1) = p = 1/2.

# %% [markdown]
# ## Binomial Distribution:

# %% [markdown]
# The most widely known discrete probability distribution. It has been used hundreds of
# years.

# %% [markdown]
# A probability distribution concludes the value that takes one of two independent values under a set of assumptions or parameters. Besides, the binomial distribution’s assumptions must have a single result with the same probability of success. And that trail must be independent of each other.

# %% [markdown]
# ###### Assumptions:
#
# 1. The experiment involves n identical trials.
# 2. Each trial has only two possible outcomes – success or failure.
# 3. Each trial is independent of the previous trials.
# 4. The terms p and q remain constant throughout the experiment, where p is the probability of getting a success on any one trial and q = (1 – p) is the probability of getting a failure on any one trial

# %% [markdown]
# ###### For Example
#
# To know the side effects of medication, medical specialists use binomial distribution. Through this, they get to know the number of patients who experience the side effects of taking new medications.

# %% [markdown]
# ![Capture2.JPG](attachment:Capture2.JPG)
#
# ![Capture4.JPG](attachment:Capture4.JPG)

# %% [markdown]
# ## Uniform distribution

# %% [markdown]
# The basic form of a continuous distribution is known as uniform distribution. It has the constant probability that it forms a rectangular distribution. And it implies that each value has the same length of distribution. Which has an equal probability of occurrence. In contrast, this function belongs to the type of maximum entropy probability distributions.

# %% [markdown]
# ###### Characteristics of uniform distribution

# %% [raw]
# The density function combines to unity.
# Each of its input functions has equal weightage.
# The uniform function’s mean is given by:
#
# mean = (a+b)/ 2
#
# The variance of the uniform distribution is given by:
#
# Variance = square of (b - a)  / 12

# %% [markdown]
# ###### For Example
# An example of a uniform distribution is a deck of cards. The reason behind this is an individual has an equal opportunity to draw a spade, a heart, a diamond, or a club.

# %% [markdown]
# ![Capture1.JPG](attachment:Capture1.JPG)

# %% [markdown]
# ## Poisson distribution

# %% [markdown]
# It is a tool that is used to predict a certain probability of the event when you know the value of a certain event. The Poisson distribution provides us the probability of an applied number of events that happen in a fixed period of time.

# %% [markdown]
# The Poisson distribution is a probability distribution for discrete data which takes on the values which are X = 0, 1, 2, 3 and so on.

# %% [markdown]
# The Poisson distribution is a discrete probability distribution that expresses the probability of a given number of events occurring in a fixed interval of time or space if these events occur with a known constant mean rate and independently of the time since the last event

# %% [markdown]
# ###### Properties of Poisson distribution

# %% [raw]
# The expected value and variance of the random variable are equivalents to λ.
# The absolute deviation is associated with the mean is given by:

# %% [markdown]
# ###### For Example
# Call centers apply the Poisson Distribution to display the numbers of expected calls they will receive per hour. As a result, they get an overall of how many call center representatives they need to require.

# %% [markdown]
# ###### When to Use the Poisson Distribution?

# %% [markdown]
# The Poisson distribution is often used as a model for the number of events (such as the number of telephone calls at a business, the number of accidents at an intersection, number of calls received by a call center agent etc.) in a specific time period. The Poisson distribution is used when it is desired to determine the probability of the number of occurrences on a per-unit basis, for instance, per-unit time, per-unit area, per-unit volume etc. In other words, the Poisson distribution is the probability distribution that results from a Poisson experiment. The Poisson distribution is suitable for analyzing situations where the number of trials is very large and the probability of success is very small.

# %% [markdown]
# ![Capture1.JPG](attachment:Capture1.JPG)

# %% [markdown]
# # Exponential distribution

# %% [markdown]
# It is also known as a negative exponential distribution that represents the time between the trails in a Poisson process. The relationship between the exponential distribution and Poisson distribution.

# %% [markdown]
# The exponential distribution is the probability distribution of the time between events in a Poisson point process, i.e., a process in which events occur continuously and independently at a constant average rate.

# %% [markdown]
# ###### For Example
# An exponential distribution models the time between two earthquake occurrences.

# %% [markdown]
# ![Capture1.JPG](attachment:Capture1.JPG)

# %% [markdown]
# ###### Probability Density Function (PDF) –
#
# It calculates probability of observing given value.

# %% [markdown]
# ###### Cumulative Density Function (CDF) –
#
# It calculates probability of an observation equal or less than value.

# %% [markdown]
# ### PDF , CDF & PMF

# %% [markdown]
# Two of the most important statistical functions in a nutshell. The PDF and CDF statistical
# functions are widely used techniques in the Exploratory Data Analysis to find the
# probabilistic relationships between the variables

# %% [markdown]
# ###### Probability Density Function (PDF)

# %% [markdown]
# The probability density function (PDF)
# is the probability that a random
# variable, say X, will take a
# value exactly equal to X. – The PDF
# focuses on one specific value. Whereas,
# for the cumulative distribution function,
# we are interested in the probability of
# taking on a value equal to or less than
# the specified value. The probability
# density function is also referred to as
# the probability mass function (PMF).

# %% [markdown]
# ###### Cumulative Distribution Function (CDF)

# %% [markdown]
# The cumulative distribution function (CDF) is the probability that a random variable, say X,
# will take a value equal to or less than x.

# %% [markdown]
# ###### Probability Mass Function (PDF)

# %% [markdown]
# ###### Example
# Rolling a dice.....(UNIFORM DISTRIBUTION)

# %% [markdown]
# ![Capture1.JPG](attachment:Capture1.JPG)

# %% [markdown]
# ###### Example
# Height of a women in India.....(NORMAL DISTRIBUTION)

# %% [markdown]
# ![Capture1.JPG](attachment:Capture1.JPG)

# %% [markdown]
# ###### Why should we use PDF, CDF?

# %% [markdown]
# PDFs, CDFs are widely used in data analysis. Once the distribution of data, mean, and
# variance of the data is known, it is easy to plot PDF and CDF. These plots can help find
# solutions to many problems in data analysis.
