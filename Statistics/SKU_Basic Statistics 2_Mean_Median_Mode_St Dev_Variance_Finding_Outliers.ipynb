# %% [markdown]
# # Statistics

# %% [markdown]
# Statistical methods and equations can be applied to a data set in order to analyze and interpret results, explain variations in the data, or predict future data.
#
# Statistics is important in the field of engineering by it provides tools to analyze collected data.
#
# Statistics is a branch that deals with every aspect of the data.
#
# The science of collecting and studying these numbers.
#
# Statistics is a branch of science that deals with the collection, organisation, analysis of data and drawing of inferences from the samples to the whole population.
#
# Statistics is about understanding the art and science of the collection of data, the frequency, and the distribution of the trends.

# %% [markdown]
# ## Basic Concept of Statistics

# %% [markdown]
# When performing statistical analysis on a set of data, the mean, median, mode, and standard deviation, etc are all helpful values to calculate.

# %% [markdown]
# ###### Mean

# %% [markdown]
# The Mean is also known as the 'average'. We can get the Mean by summing all the data values and then divided by it with total numbers of data points.
#
# The mean is the sum of all the values in the data divided by the total number of values in
# the data.

# %% [markdown]
# You can calculate the mean for both the population and the sample.
#
# Calculating the population mean (μ) and sample mean (x) is done with this formula:

# %% [markdown]
# ![Capture2.JPG](attachment:Capture2.JPG)

# %%
values = [2,4,5,2,8,3,12]
import numpy as np
mean = np.mean(values)
mean
# Out:
# 5.142857142857143

# %% [markdown]
# ###### Median

# %% [markdown]
# The Median is the middle value of the given dataset if total data points is odd number. Or the average of two middle values if thetotal data points is even number.
# It is highly important when seperating the dataset into two equal bins.

# %%
values = [2,4,5,2,8,3,12]
import numpy as np
mean = np.median(values)
mean
# Out:
# 4.0

# %% [markdown]
# ###### Mode

# %% [markdown]
# The mode of the dataset is the datapoint which occurs maximum times.
#
# Mode is the most repetitive value of a given set of values.

# %%
values = [2,4,5,2,8,3,12]
import statistics as stat
mean = stat.mode(values)
mean
# Out:
# 2

# %% [markdown]
# ##### Variance

# %% [markdown]
# Variance is a measure of how data points differ from the mean.
#
# Variance is use to get how far the data points are from the mean value.
#
# Variance is the expected value of the squared variation of a random variable from its mean value, in probability and statistics. Informally, variance estimates how far a set of numbers (random) are spread out from their mean value

# %% [markdown]
# ###### How to Calculate Variance

# %% [raw]
# > Find the mean of the given data set. Calculate the average of a given set of values
# > Now subtract the mean from each value and square them
# > Find the average of these squared values, that will result in variance

# %% [markdown]
# ###### Covariance
#
# Covariance is a measure of the relationship between two random variables, in statistics. The covariance indicates the relation
# between the two variables and helps to know if the two variables vary together.

# %% [markdown]
# ![Capture1.JPG](attachment:Capture1.JPG)

# %% [markdown]
# ###### Standard Deviation

# %% [markdown]
# Standard deviation is use to get the dispersion of datapoints from the mean in a given dataset.
#
# It is the square root of variance of dataset.

# %%
import numpy as np
items = (2,4,5,6,4,7,8,9,1,32)
st_dev = np.std(items)
st_dev
# Out:
# 8.411896337925237

# %% [markdown]
# ### Measures of dispersion

# %% [markdown]
# ###### Range

# %% [markdown]
# Range is the number which we get after subtracting the maximum value with minimum value of given dataset.

# %%
items = (2,4,5,6,4,7,8,9,1,32)
my_min = min(items)
my_max = max(items)
my_range = my_max-my_min
print('Range of given dataset is :  ' , my_range)
# Out:
# Range of given dataset is :   31

# %% [markdown]
# ###### Quartiles

# %% [markdown]
# The quartiles data into three points—a lower quartile, median, and upper quartile—to form four groups of the dataset.

# %% [markdown]
# Quartiles are used to calculate the interquartile range, which is a measure of variability around the median.

# %% [markdown]
# ###### Lower quartile (first quartile)

# %% [markdown]
# The lower quartile is the value under which 25% of data points are found when they are arranged in increasing order.

# %% [markdown]
# First Quartile(Q1) = ((n + 1)/4)th Term

# %%
items = [49,47,45,6,43,7,15, 36,39,41,41,43]
items.sort()
items
# Out:
# [6, 7, 15, 36, 39, 41, 41, 43, 43, 45, 47, 49]

# %%
lower_quar = len(items)/4
print('Lower Quartile Number : ' , lower_quar)
print ('Lower Quartile Data Point : ' , items[3-1])
Q1=items[3-1]
Q1
# Out:
# Lower Quartile Number :  3.0
# Lower Quartile Data Point :  45
# 45

# %% [markdown]
# ###### Upper quartile (third quartile)

# %% [markdown]
# The upper quartile, or third quartile (Q3), is the value under which 75% of data points are found when arranged in increasing order.

# %%
upper_quar = (len(items)/4)*3
print('Upper Quartile Number : ' , upper_quar)
print ('Upper Quartile Data Point : ' , items[9-1])
Q3 = items[9-1]
Q3
# Out:
# Upper Quartile Number :  9.0
# Upper Quartile Data Point :  43
# 43

# %% [markdown]
# ###### Middle Quartile(second quartile or Median)

# %%
middle_quar = (len(items)/2)
print('Middle Quartile Number  : ' , middle_quar)
print ('Middle Quartile or Median Data Point : ' , items[6-1])
Q2 = items[6-1]
# Out:
# Middle Quartile Number  :  6.0
# Middle Quartile or Median Data Point :  41

# %% [markdown]
# ###### inter Quartile Range (IQR)

# %% [markdown]
# The interquartile range is calculated as Upper Quartile – Lower Quartile.

# %%
IQR = Q3 - Q1 
print('Inter Quartile Range of given dataset : ', IQR)
# Out:
# Inter Quartile Range of given dataset :  28

# %%
### Showing incorrect answer
from scipy import stats
items = [49,47,45,6,43,7,15, 36,39,41,41,43]
Lower_Quartile = stats.iqr(items)
Lower_Quartile
# Out:
# 12.75

# %% [markdown]
# ###### Quartile Deviation

# %% [markdown]
# Quartile deviation is half of the distance between the third and the first quartile. It is also known as the Semi Interquartile range.

# %%
Q_Deviation = (Q3 - Q1)/2
print('Quartile Deviation of given dataset : ' , Q_Deviation)
# Out:
# Quartile Deviation of given dataset :  14.0

# %% [markdown]
# ## What is Outlier

# %% [markdown]
# An outlier is an observation which lies an abnormal distance from other datapoints in a given dataset.
#
# An outlier is an observation that lies an abnormal distance from other
# values in a random sample from a population
#
# An outlier is a data point that lies outside the overall pattern in a distribution.
#
# The Lower fence is the "lower limit" and the Upper fence is the "upper limit" of data, and any data lying outside this defined bounds can be considered an outlier.
#
# The Lower fence is the 'lower limit' and the Upper fence is the 'upper limit' of data, and any data which does not fit in the upper and lower limits (fence) is considered as the outliers.

# %% [markdown]
# ## How to detect outliers in a dataset: -

# %% [raw]
# Data points that lie 1.5 times of IQR above Q3 (75 percentile) and below Q1 (25 percentile) are outliers
#
# • Sort the dataset in ascending order
# • calculate the 1st and 3rd quartiles (Q1, Q3) [Box plot]
# • compute IQR=Q3-Q1 (Q1, Q3- lower, higher fence)
# • compute lower fence = (Q1–1.5*IQR), upper fence = (Q3+1.5*IQR)
# • loop through the values of the dataset and check for those who fall below the lower
# bound and above the upper bound and mark them as outliers

# %% [markdown]
# ###### Lower Inner Fence

# %% [markdown]
# LF = Q1 - 1.5 * IQR

# %% [markdown]
# ###### Upper Inner Fence

# %%
UF = Q3 + 1.5 * IQR

# %% [markdown]
# ### Question:

# %% [markdown]
# ###### Find all statistical values of given dataset?
# list1 = [5, 3, 6, 7, 2, 1, 9, 23]

# %% [raw]
# Lower fence: -7.125
# Upper fence: 17.875
# Other statistical characteristics:
# Average (mean): μ=7
# Absolute deviation: 36
# Mean deviation: 4.5
# Minimum: 1
# Maximum: 23
# Variance: 42.75
# Standard deviation σ=6.538348415311
# Corrected sample standard deviation s=6.9897884701286
# Coefficient of variation cV=0.99854121001837
# Signal-to-noise ratio SNR=1.0014609211588
# Median: 5.5
# Quartile Q1: 2.25
# Quartile Q2: 5.5
# Quartile Q3: 8.5

# %% [markdown]
# ###### Example 2   How to detect outliers in a dataset:

# %%
Dataset= [30, 171, 184, 201, 212, 250, 265, 270, 272, 289, 305, 306, 322, 322, 336, 346, 351, 
370, 390, 404, 409, 411, 436, 437, 439, 441, 444, 448, 451, 453, 470, 480, 482, 487, 494, 
495, 499, 503, 514, 521, 522, 527, 548, 550, 559, 560, 570, 572, 574, 578, 585, 592, 592, 
607, 616, 618, 621, 629, 637, 638, 640, 656, 668, 707, 709, 719, 737, 739, 752, 758, 766, 
792, 792, 794, 802, 818, 830, 832, 843, 858, 860, 869, 918, 925, 953, 991, 1000, 1005, 1068, 
1441]

# %% [raw]
# Lower quartile = 0.25(N+1)th ordered point = 22.75th ordered point = 411 + 0.75(436-411) = 429.75
# Upper quartile = 0.75(N+1)th ordered point = 68.25th ordered point = 739 +0.25(752-739) = 742.25
# Interquartile range (IQR) = 742.25 - 429.75 = 312.5
# Lower fence = 429.75 - 1.5 (312.5) = -39.0
# Upper fence = 742.25 + 1.5 (312.5) = 1211.0

# %% [markdown]
# Clearly observed the upper fence is 1211 but, in our Dataset, only 1441 is available after
# point 1211, so 1441 is an outlier
