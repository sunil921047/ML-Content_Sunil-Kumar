# %% [markdown]
# # Hypothesis

# %% [markdown]
# A hypothesis is an assumption, an idea that is proposed for the sake of argument so that it can be tested to see if it might be true.
#
# A hypothesis is an idea which is suggested as a possible explanation for a particular situation or condition, but which has not yet been proved to be correct.
#
# An idea or explanation for something that is based on known facts but has not yet been proved:

# %% [markdown]
# ### Estimate

# %% [markdown]
# There are two important types of estimates you can make about the population: point estimates and interval estimates.

# %% [raw]
# • A point estimate is a single value estimate of a parameter. For instance, a sample mean is a point estimate of a population mean.
# • An interval estimate gives you a range of values where the parameter is expected to lie. A confidence interval is the most common type of interval estimate.

# %% [markdown]
# ### Confidence Interval

# %% [markdown]
# The confidmence interval is a type of interval estimate from the sampling distribution which
# gives a range of values in which the population statistic may lie.
#
# Confidence intervals provide information about a range in which the true value lies with a certain degree of probability,

# %% [raw]
# Confidence levels can be expressed as percentages or decimal numbers, and the most commonly used are:
# • 90% (0.90)
# • 95% (0.95)
# • 99% (0.99)
# The higher the confidence level, the bigger the interval will be

# %% [raw]
# For example, the confidence intervals for the average height of people in Denmark might be:
# • 90% confidence level: between 175 cm and 185 cm.
# • 95% confidence level: between 170 cm and 190 cm.
# • 99% confidence level: between 160 cm and 200 cm.
# We use this confidence level together with a probability distribution to decide how large the margin of error  is

# %% [markdown]
# ### Steps for Calculating the Confidence Interval

# %% [raw]
# The following steps are used to calculate a confidence interval:
# 1. Check the conditions
# 2. Find the point estimate
# 3. Decide the confidence level
# 4. Calculate the margin of error
# 5. Calculate the confidence interval

# %% [markdown]
# ###### Where:

# %% [raw]
# • CI = confidence interval
# • X̄ = population mean (point of estimate)
# • Z* = critical value of the z-distribution
# • σ = population standard deviation
# • √n = square root of the population size

# %% [markdown]
# ![Capture11.JPG](attachment:Capture11.JPG)

# %% [markdown]
# ![Capture12.JPG](attachment:Capture12.JPG)

# %% [markdown]
# ### The Margin of Error

# %% [raw]
# The margin of error is the distance between the point estimate and the lower and upper bounds.
# The margin of error is based on the confidence level and the data we have from the sample.
# For example, if the point estimate for the average height of people in Denmark is 180 cm:
#
#     5 cm margin of error: between 175 cm and 185 cm.

# %% [markdown]
# ## Significance value = alpha
#
# Significance value also known as  alpha.
#
# The significance level (α) is the uncertainty we accept when rejecting the
# null hypothesis in the hypothesis test
#
#  if you use an alpha value of p < 0.05 for statistical significance, then your confidence level would be 1 − 0.05 = 0.95, or 95%
#
#  The significance level is a percentage probability of accidentally making the
# wrong conclusion.

# %% [markdown]
# ###### Typical significance levels are:

# %% [raw]
# • α=0.1 (10%)
# • α=0.05 (5%)
# • α=0.01 (1%)

# %% [markdown]
# ###### Confidence level = 1 – a

# %% [markdown]
# A lower significance level means that the evidence in the data needs to be
# stronger to reject the null hypothesis.
#
# There is no "correct" significance level - it only states the uncertainty of the
# conclusion.

# %% [markdown]
# ###### Note:
# A 5% significance level means that when we reject a null hypothesis:
#
# We expect to reject a true null hypothesis 5 out of 100 times.

# %% [markdown]
# We have a 95% confidence interval and the significance value is 0.025 on each tail.

# %% [markdown]
# ##### How to select the best Hypothesis Test

# %% [markdown]
# ![Capture13.JPG](attachment:Capture13.JPG)

# %% [markdown]
# ![Capture15.JPG](attachment:Capture15.JPG)

# %% [markdown]
# ###### Example1:

# %% [markdown]
# Class 8th has a mean score of 40 marks out of 100. The principal of the school
# decided that extra classes are necessary in order to improve the performance of the class. The
# class scored an average of 45 marks out of 100 after taking extra classes. Can we be sure
# whether the increase in marks is a result of extra classes or is it just random?

# %% [markdown]
# Hypothesis testing is defined in two terms – Null Hypothesis and Alternate Hypothesis.

# %% [markdown]
# To be clear when we get the Hypothesis test value within the confidence interval/level that
# means we conclude that we fail to reject the null hypothesis on the other hand if the
# hypothesis-test value is outside of the confidence interval there we reject the null hypothesis.

# %% [markdown]
# ![Capture16.JPG](attachment:Capture16.JPG)

# %% [markdown]
# ###### Example1:   T-Test

# %% [markdown]
# A population has a mean weight of 68 kg. A random sample of size 25 has a
# mean weight of 70 with a standard deviation of 4. Identify whether this sample is
# representative of the population.

# %% [markdown]
# ###### Step 1: State the Null and Alternate Hypothesis
# Null Hypothesis: The sample mean and population mean are the same.
#
# Alternate Hypothesis: The sample mean and population mean are different.

# %% [markdown]
# ###### Step 2: Calculate the appropriate test statistic
#
# df = 25-1 =24 [ df (degrees of freedom)= sample size-1]
#
# t= (70-68)/(4/√25) = 2.5
#
# Now, for a 95% confidence level, the t-critical (two-tail) for rejecting Null Hypothesis for 24 d.f is 2.06 . Hence, we can reject the Null Hypothesis and conclude that the two means are
# different.

# %% [markdown]
# ![Capture17.JPG](attachment:Capture17.JPG)

# %% [markdown]
# ### Critial Region / Critical Rejection

# %% [markdown]
# ### One Tail Test / Two Tail Test

# %% [markdown]
# ![Capture11.JPG](attachment:Capture11.JPG)

# %% [markdown]
# ## Central Limit Theoram

# %% [markdown]
# ![Capture12.JPG](attachment:Capture12.JPG)

# %% [markdown]
# ###### Classification of Hypothesis

# %% [markdown]
# Parametric
#
# Non Parametric
