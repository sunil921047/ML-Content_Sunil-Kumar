# %% [markdown]
# ## Module 6: Data Manipulation Using Pandas

# %% [markdown]
# #### Question 1

# %% [markdown]
# You are given a dataset, which is present in the LMS, containing the number of hurricanes occurring in the United States along the coast of the Atlantic. Load the data from the dataset into your program and plot a Bar Graph of the data, taking the Year as the x-axis and the number of hurricanes occurring as the Y-axis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Hurricanes.csv")
df.head(3)
# Out:
#    Year  Hurricanes
# 0  1914           0
# 1  1915           5
# 2  1916          10

# %%
plt.bar('Year' , 'Hurricanes' , data = df)
plt.ylable = 'Year'
plt.xlable = 'Hurricanes'
plt.title = 'United States Hurricanes'
plt.show()

# %% [markdown]
# #### Question 2

# %% [markdown]
# The dataset given, records data of city temperatures over the years 2014 and 2015. Plot the histogram of the temperatures over this period for the cities of San Francisco and Moscow.

# %%
df_city = pd.read_csv("CityTemps.csv")
df_city.head(3)
# Out:
#    Year  Month  Moscow  Melbourne  San Francisco
# 0  2014      1    -8.6       22.0           12.8
# 1  2014      2    -1.9       21.5           12.7
# 2  2014      3     2.8       19.5           15.0

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

df = pd.read_csv('CityTemps.csv')
moscow = df['Moscow']
sanFrancisco=df['San Francisco']
melbourne=df['Melbourne']
bins = np.linspace(0, 24, 2)
labels = ['moscow', 'sanFrancisco', 'melbourne']
plt.hist(moscow, label='moscow')
plt.hist(sanFrancisco, bins)
plt.hist(melbourne, bins)
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Question 3

# %% [markdown]
# Plot a pie-chart of the number of models released by every manufacturer, recorded in the data provide. Also mention the name of the manufacture with the largest releases. - (DataSet - Cars 2015)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_car = pd.read_csv('Cars2015.csv')
df_car.head(3)
# Out:
#         Make   Model       Type  LowPrice  HighPrice Drive  CityMPG  HwyMPG  \
# 0  Chevrolet   Spark  Hatchback    12.270     25.560   FWD       30      39
# 1    Hyundai  Accent  Hatchback    14.745     17.495   FWD       28      37
# 2        Kia     Rio      Sedan    13.990     18.290   FWD       28      36
#
#    FuelCap  Length  Width  Wheelbase  Height  UTurn  Weight  Acc030  Acc060  \
# 0      9.0     145     63         94      61     34    2345     4.4    12.8
# 1     11.4     172     67        101      57     37    2550     3.7    10.3
# 2     11.3     172     68        101      57     37    2575     3.5     9.5
#
#    QtrMile  PageNum   Size
# 0     19.4      123  Small
# 1     17.8      148  Small
# 2     17.3      163  Small

# %%
manufacture = df_car.iloc[: , 0:1 ]
manufacture.head(2)
df2=manufacture.groupby('Make')
new_df1= pd.DataFrame(data=list(df2))
new_df1
# Out:
#              0                                                  1
# 0        Acura                         Make
# 44   Acura
# 107  Acura
# 1         Audi      Make
# 16  Audi
# 32  Audi
# 41  Audi
# 50  Audi
# 5...
# 2          BMW       Make
# 18  BMW
# 42  BMW
# 54  BMW
# 58  BMW
# 79  BMW
# 3        Buick                 Make
# 33  Buick
# 46  Buick
# 92  Buick
# 4       Buick                                     Make
# 77  Buick
# 5     Cadillac           Make
# 34   Cadillac
# 43   Cadillac
# 59  ...
# 6    Chevrolet            Make
# 0    Chevrolet
# 22   Chevrolet
# 4...
# 7   Chevrolet                                  Make
# 6  Chevrolet
# 8     Chrysler          Make
# 23  Chrysler
# 47  Chrysler
# 95  Chr...
# 9        Dodge                           Make
# 5   Dodge
# 91  Dodge
# 10      Dodge               Make
# 48  Dodge
# 62  Dodge
# 96  Dodge
# 11        Fiat                                       Make
# 7  Fiat
# 12        Ford       Make
# 8    Ford
# 30   Ford
# 49   Ford
# 73   F...
# 13       Ford                                      Make
# 13  Ford
# 14        GMC                            Make
# 103  GMC
# 109  GMC
# 15      Honda         Make
# 24  Honda
# 69  Honda
# 86  Honda
# 97...
# 16     Hyundai          Make
# 1    Hyundai
# 15   Hyundai
# 28   Hy...
# 17    Infiniti                     Make
# 35  Infiniti
# 88  Infiniti
# 18      Jaguar                         Make
# 38  Jaguar
# 53  Jaguar
# 19        Jeep                             Make
# 80  Jeep
# 89  Jeep
# 20         Kia       Make
# 2   Kia
# 17  Kia
# 29  Kia
# 56  Kia
# 70  Kia
# 21  Land Rover                                Make
# 81  Land Rover
# 22       Lexus                           Make
# 40  Lexus
# 52  Lexus
# 23     Lincoln                       Make
# 82  Lincoln
# 93  Lincoln
# 24    Maserati                                  Make
# 39  Maserati
# 25       Mazda                 Make
# 10  Mazda
# 19  Mazda
# 74  Mazda
# 26      Mazda                                     Make
# 66  Mazda
# 27    Mercedes                     Make
# 36  Mercedes
# 67  Mercedes
# 28  Mitsubishi                                 Make
# 3  Mitsubishi
# 29      Nissan         Make
# 4    Nissan
# 14   Nissan
# 25   Nissa...
# 30      Porche                         Make
# 64  Porche
# 65  Porche
# 31       Scion                           Make
# 21  Scion
# 75  Scion
# 32      Subaru              Make
# 11  Subaru
# 71  Subaru
# 84  Subaru
# 33     Subaru                                    Make
# 26  Subaru
# 34      Toyoto         Make
# 9    Toyoto
# 27   Toyoto
# 76   Toyot...
# 35  Volkswagon            Make
# 12  Volkswagon
# 20  Volkswagon
# 3...
# 36       Volvo                           Make
# 37  Volvo
# 72  Volvo

# %% [markdown]
# #### Question 4

# %% [markdown]
# Create csv file from the data below and read in pandas data frame

# %% [markdown]
# #### Question 5

# %% [markdown]
# Phase 2 –Describe the data
#
# Describe the data on the unit price

# %% [markdown]
# #### Question 6

# %% [raw]
# Phase 3 –filter the data
# Create new dataframe having columns 'name','net_price','date' and group all the records according to name

# %% [markdown]
# #### Question 7

# %% [markdown]
# Phase 4 –Plotting graph
#
# Plot the graph after calculating total sales by each customer. Customer name should be on x axis and total sales in y axis.

# %% [markdown]
# #### Question 8

# %% [markdown]
# Let the x axis data points and y axis data points are
# X = [1,2,3,4] y = [20, 21, 20.5, 20.8]
# 5.1: Draw a Simple plot
# 5.2: Configure the line and markers in simple plot
# 5.3: configure the axes
# 5.4: Give title of Graph & labels of x axis and y axis
# 5.5: Give error bar if y_error = [0.12, 0.13, 0.2, 0.1]
# 5.6: define width, height as figsize=(4,5) DPI and adjust plot dpi=100
# 5.7: Give a font size of 14
# 5.8: Draw a scatter graph of any 50 random values of x and y axis
# 5.9: Create a dataframe from following data
# 'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
# 'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
# 'female': [0, 1, 1, 0, 1],
# 'age': [42, 52, 36, 24, 73],
# 'preTestScore': [4, 24, 31, 2, 3],
# 'postTestScore': [25, 94, 57, 62, 70]
# Draw a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age

# %% [markdown]
# ####  Question 9

# %% [markdown]
# 5.10: Draw a Scatterplot from the data in question 9 of preTestScore and postTestScore with the size = 300 and the color determined by sex
